# %%
import pandas as pd
import pickle

# %%
songs = pd.read_csv("songs.csv")
train = pd.read_csv("train.csv")[:100]
members = pd.read_csv("members.csv")
sample_submission = pd.read_csv("sample_submission.csv")

# %%
# Serialize into dict
song_user = train[['song_id', 'msno']].set_index('song_id').groupby('song_id')['msno'].apply(list).to_dict()
with open('song_user.dict', 'wb') as handle:
    pickle.dump(song_person, handle, protocol=pickle.HIGHEST_PROTOCOL)
user_song = train[['msno', 'song_id']].set_index('msno').groupby('msno')['song_id'].apply(list).to_dict()
with open('user_song.dict', 'wb') as handle:
    pickle.dump(user_song, handle, protocol=pickle.HIGHEST_PROTOCOL)
song_id = train[['song_id']].sort_values(by='song_id')
with open('song_id.txt', 'wb') as handle:
    pickle.dump(song_id, handle, protocol=pickle.HIGHEST_PROTOCOL)
user_id = train[['msno']].sort_values(by='msno')
with open('user_id.txt', 'wb') as handle:
    pickle.dump(user_id, handle, protocol=pickle.HIGHEST_PROTOCOL)
user_song_tuple = train[['msno', 'song_id']].sort_values(by='msno').to_string(header=False, index=False, index_names=False).split('\n')
user_song_tuple = ['\t'.join(row.split()) for row in user_song_tuple]
with open('user_song_tuple.txt', 'wb') as handle:
    pickle.dump(user_song_tuple, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# # Load data check(deserialize)
# with open('song_person.dict', 'rb') as handle:
#     unserialized_song_person = pickle.load(handle)
# unserialized_song_person['BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=']
df = pd.DataFrame({'msno': ['a','b', 'a'], 'song_id': [3, 4,1]})
user_song_tuple = df.sort_values(by='msno').to_string(header=False, index=False, index_names=False).split('\n')
user_song_tuple = ['\t'.join(row.split()) for row in user_song_tuple]
user_song_tuple
with open('user_song_tuple.txt', 'wb') as handle:
    pickle.dump(user_song_tuple, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
train.head
# Out:
# <bound method NDFrame.head of                                             msno  \
# 0   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 5   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 6   Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 7   FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 8   uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 9   uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 10  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 11  uHqAtShXTRXju5GE8ri3ITsVFepPf8jUoCF7ffNOuqE=
# 12  TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 13  3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 14  TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# 15  3g0bC24RD7QUeALY1IF/e8L6X3fHG298ZFIsCEG9T9Y=
# 16  TJU0Gfvy7FB+r89bWovPKXTjuApTCiv3xg/tt5shR78=
# ...
